# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('realtor-data.csv')
df.head()
# Out:
#      status  bed  bath  acre_lot        city        state  zip_code  \
# 0  for_sale  3.0   2.0      0.12    Adjuntas  Puerto Rico     601.0
# 1  for_sale  4.0   2.0      0.08    Adjuntas  Puerto Rico     601.0
# 2  for_sale  2.0   1.0      0.15  Juana Diaz  Puerto Rico     795.0
# 3  for_sale  4.0   2.0      0.10       Ponce  Puerto Rico     731.0
# 4  for_sale  6.0   2.0      0.05    Mayaguez  Puerto Rico     680.0
#
#    house_size prev_sold_date     price
# 0       920.0            NaN  105000.0
# 1      1527.0            NaN   80000.0
# 2       748.0            NaN   67000.0
# 3      1800.0            NaN  145000.0
# 4         NaN            NaN   65000.0

# %%
df.shape
# Out:
# (1401066, 10)

# %%
sns.scatterplot(df,x='bed',y='price')
plt.show()

# %%
sns.scatterplot(df,x='bath',y='price')
plt.show()

# %%
sns.scatterplot(df,x='acre_lot',y='price')
plt.show()

# %%
sns.scatterplot(df,x='zip_code',y='price')
plt.show()

# %%
sns.scatterplot(df,x='house_size',y='price')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.countplot(df,x='bed')
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.xticks(rotation=60)
sns.countplot(df,x='bath')
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.xticks(rotation=60)
sns.barplot(x='bed',y='bath',data=df)
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.xticks(rotation=60)
sns.barplot(x='bed',y='acre_lot',data=df)
plt.show()
# Out:
# C:\Users\power\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# C:\Users\power\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# C:\Users\power\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\nanfunctions.py:1559: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a,
# C:\Users\power\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# C:\Users\power\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\nanfunctions.py:1559: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a,
# ...

# %%
plt.figure(figsize=(10,7))
plt.xticks(rotation=60)
sns.barplot(x='bath',y='acre_lot',data=df)
plt.show()
# Out:
# C:\Users\power\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# C:\Users\power\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# C:\Users\power\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\nanfunctions.py:1559: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a,
# C:\Users\power\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# C:\Users\power\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\nanfunctions.py:1559: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a,

# %%
sns.boxplot(df['bed'])
plt.show()

# %%
sns.boxplot(df['bath'])
plt.show()

# %%
sns.boxplot(df['acre_lot'])
plt.show()

# %%
sns.boxplot(df['house_size'])
plt.show()

# %%
sns.boxplot(df['price'])
plt.show()

# %%
df.shape
# Out:
# (1401066, 10)

# %%
plt.figure(figsize=(10,7))
correlation=df.corr()
sns.heatmap(correlation,cbar=True,square=True,fmt='.1f',annot=True,annot_kws={'size':15},cmap='Blues')
plt.show()
# Out:
# C:\Users\power\AppData\Local\Temp\ipykernel_3640\2915534740.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=df.corr()
